# %% [markdown]
# # Самостоятельная работа (Кортежи. Создание функций)

# %% [markdown]
# ## Задача 1. Срез кортежа

# %% [markdown]
# Кладовщик ведет учет товаров, поступающих партиями. По его записям, внесенным в базу данных, сформирован следующий кортеж `(4, 16, 45, 8, 34, 14, 18, 24, 13, 18, 40, 47, 7, 12, 16)`, описывающий количество товаров, принятых на склад в каждом месяце.
#
# Напишите программу, которая позволит поставщику отобрать количество поступивших товаров в каждом втором месяце.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# (4, 16, 45, 8, 34, 14, 18, 24, 13, 18, 40, 47, 7, 12, 16)
# ```
#
# **Вывод:**
#
# ```
# (16, 8, 14, 24, 18, 47, 12)
# ```

# %%
# дополните код в этой ячейке
baza = (4, 16, 45, 8, 34, 14, 18, 24, 13, 18, 40, 47, 7, 12, 16)
# Out:
#   Cell In[22], line 2
#     baza =
#           ^
# SyntaxError: invalid syntax

# %%
# ваш код в этой ячейке
def select_every_second_month(baza):
    selected_baza = []
    for i in range(len(baza)):
        if i % 2 != 0:
            selected_baza.append(baza[i])
    return selected_baza

# Входные данные
baza = (4, 16, 45, 8, 34, 14, 18, 24, 13, 18, 40, 47, 7, 12, 16)

# Выбор каждого второго месяца
selected_baza = select_every_second_month(baza)

# Вывод результатов
print("Количество товаров в каждом втором месяце:")
for i, baza in enumerate(selected_baza, start=1):
    print(f"Месяц {i * 2}: {baza}")
# Out:
# Количество товаров в каждом втором месяце:
# Месяц 2: 16
# Месяц 4: 8
# Месяц 6: 14
# Месяц 8: 24
# Месяц 10: 18
# Месяц 12: 47
# Месяц 14: 12

# %% [markdown]
# ## Задача 2. Конференция

# %% [markdown]
# Студенты кафедры МИРЭА готовятся к проведению конференции по экономике и праву и формируют пакеты участников, в которых должен лежать стандартный набор: `('программа конференции', 'блокнот', 'ручка', 'магнитик')`. Чтобы ничего не пропустить, студенты формируют перечень раздаточных материалов, в котором перечисляют каждый их них столько раз, сколько на конференции будет участников `participants`, а затем, как только кладут вещь в пакет, вычеркивают ее из общего перечня.
#
# Напишите программу, которая запросит количество участников конференции и поможет студентам создать перечень раздаточных материалов, откуда они будут вычеркивать позиции по мере формирования пакетов.
#
# ***Примечание:*** стандартный набор вводится кортежем, вывод необходимо осуществить также с помощью кортежа.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# 20
#
# ```
#
# **Вывод:**
#
# ```
# ('программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик', 'программа конференции', 'блокнот', 'ручка', 'магнитик')
# ```

# %%
# дополните код в этой ячейке
pack = ('программа конференции', 'блокнот', 'ручка', 'магнитик')
participants = int(input("Введите количество участников конференции: "))

# %%
# ваш код в этой ячейке
def create_distribution_list(participants):
    pack = ('программа конференции', 'блокнот', 'ручка', 'магнитик')
    distribution_list = pack * participants
    return distribution_list

# Запрос количества участников конференции
participants = int(input("Введите количество участников конференции: "))

# Создание перечня раздаточных материалов
materials = create_distribution_list(participants)

# Вывод перечня раздаточных материалов
print("Перечень раздаточных материалов:")
print(materials)
# Out:
# Перечень раздаточных материалов:
# ...

# %% [markdown]
# ## Задача 3. Статистика раскрытых дел

# %% [markdown]
# Муниципальный отдел ведет статистику количества ежемесячно раскрытых дел. За два года такая статистика имеет вид: `(24, 37, 49, 83, 12, 46, 54, 93, 27, 13, 39, 42, 69, 39, 96, 12, 40, 33, 50, 30, 29, 32, 81, 60)`.
# Определите максимальное и минимальное количество дел, раскрытых за месяц.
#
# Известно, что количество раскрытых дел в месяц не превышает 100.
#
# ***Примечание:*** решите задачу с использованием цикла `for` и без.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# (24, 37, 49, 83, 12, 46, 54, 93, 27, 13, 39, 42, 69, 39, 96, 12, 40, 33, 50, 30, 29, 32, 81, 60)
# ```
#
# **Вывод:**
#
# ```
# 96 12
# ```

# %%
# дополните код в этой ячейке
crimes = (24, 37, 49, 83, 12, 46, 54, 93, 27, 13, 39, 42, 69, 39, 96, 12, 40, 33, 50, 30, 29, 32, 81, 60)

# %%
# ваш код в этой ячейке (решение с циклом for)
crimes = (24, 37, 49, 83, 12, 46, 54, 93, 27, 13, 39, 42, 69, 39, 96, 12, 40, 33, 50, 30, 29, 32, 81, 60)

max_cases = crimes[0]
min_cases = crimes[0]

for cases in crimes:
    if cases > max_cases:
        max_cases = cases
    if cases < min_cases:
        min_cases = cases

print("Максимальное количество дел:", max_cases)
print("Минимальное количество дел:", min_cases)
# Out:
# Максимальное количество дел: 96
# Минимальное количество дел: 12

# %%
# ваш код в этой ячейке (решение без цикла for)
crimes = (24, 37, 49, 83, 12, 46, 54, 93, 27, 13, 39, 42, 69, 39, 96, 12, 40, 33, 50, 30, 29, 32, 81, 60)

max_cases = max(crimes)
min_cases = min(crimes)

print("Максимальное количество дел:", max_cases)
print("Минимальное количество дел:", min_cases)
# Out:
# Максимальное количество дел: 96
# Минимальное количество дел: 12

# %% [markdown]
# ## Задача 4. Затраты на закупку

# %% [markdown]
# Экономист подсчитывает затраты на закупку товаров. Напишите функцию `multy()`, которая принимает количество товара `volume` в качестве первого аргумента и цену `price` в качестве второго аргумента и возвращает их произведение.
#
# Вызовите вашу функцию и выведите на экран результат ее работы.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# multy(10, 100)
#
# ```
# **Вывод:**
#
# ```
# 1000
# ```

# %%
# создайте вашу функцию в этой ячейке
def multy(volume, price):
    return volume * price

# %%
# продемонстрируйте работу функции в этой ячейке
def multy(volume, price):
    return volume * price
result = multy(10, 100)  # Пример: 10 товаров по 5 за единицу
print("Результат умножения:", result)
# Out:
# Результат умножения: 1000

# %% [markdown]
# ## Задача 5*. Числа Фибоначчи

# %% [markdown]
# В программе дана заготовка функции, которая должна принимать на вход целое положительное число n и возвращать n-ое число последовательности Фибоначчи, используя цикл for. Дополните заготовку в указанных местах так, чтобы функция выполняла поставленную задачу. Программа должна запрашивать ввод с клавиатуры целого положительного числа n и выводить на экран результат работы вашей функции — n-ное число последовательности Фибоначчи.
#
# ***СПРАВОЧНО:*** Числа Фибоначчи — числовая последовательность, первые два элемента которой — 0 и 1, а каждое последующее число равно сумме двух ему предшествующих.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# 10
# ```
#
# **Вывод:**
#
# ```
# 55
# ```

# %%
# дополните пропуски в этой ячейке
def fibon(num):
    num1 = num2 = 1
    if num < 2:
        return num
    for i in range(2, num):
        num1, num2 = num2, num1 + num2
    return num2

# %%
# ввод порядкового номера числа Фибоначчи и демонстрация работы функции fibon()
def fibon(num):
    num1 = num2 = 1
    if num < 2:
        return num
    for i in range(2, num):
        num1, num2 = num2, num1 + num2
    return num2
n = int(input("Введите порядковый номер числа Фибоначчи: "))
result = fibon(n)
print("n-ное число последовательности Фибоначчи:", result)
# Out:
# n-ное число последовательности Фибоначчи: 844617150046923109759866426342507997914076076194

# %% [markdown]
# ## Задача 6*. Алгоритм Евклида

# %% [markdown]
# Алгоритм Евклида для поиска НОД.
#
# НОД – наибольший общий делитель, – число, делящее без остатка пару чисел и являющееся наибольшим из возможных делителей. Например: НОД(8, 6)=2; НОД(12, 8)=4. Очень важное понятие, необходимость в вычислении которого возникает достаточно часто. Простой расчетной формулы для НОД не существует. Решение полным перебором возможно, но для больших чисел необходимо большое количество вычислительных операций. Хорошее решение проблемы поиска наибольшего общего делителя двух чисел нашел еще Евклид. В самом простом случае алгоритм Евклида применяется к паре положительных целых чисел и формирует новую пару, которая состоит из меньшего числа и разницы между большим и меньшим числом. Процесс повторяется, пока числа не станут равными. Найденное число и есть наибольший общий делитель исходной пары.
#
# Напишите функцию NOD, которая принимает на вход два целых числа и возвращает для них наибольший общий делитель.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# 32
# 24
# ```
#
# **Вывод:**
#
# ```
# 8
# ```

# %%
# создайте вашу функцию в этой ячейке 
def NOD(a, b):
    while b != 0:
        a, b = b, a % b
    return a

# %%
# продемонстрируйте работу функции в этой ячейке
def NOD(a, b):
    while b != 0:
        a, b = b, a % b
    return a

num1 = 32
num2 = 24
result = NOD(num1, num2)
print("Наибольший общий делитель:", result)
# Out:
# Наибольший общий делитель: 8
